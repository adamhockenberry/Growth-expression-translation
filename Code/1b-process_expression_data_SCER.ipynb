# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
from scipy import stats

import statsmodels.formula.api as smf

from matplotlib import pyplot as plt

# %% [markdown]
# **Two different sample types are contained in this dataset so we'll try and re-run the notebook to use both of them separately**
#
# Basically, make sure one is commented, run all the code. Then switch the commented line and re-run.

# %%
data_to_analyze = 'RNA'
# data_to_analyze = 'PROTEIN'

# %% [markdown]
# # Import data
#
# This data comes from here: https://elifesciences.org/articles/65722/figures

# %%
df = pd.ExcelFile(r'../Data/raw_data/elife-65722-supp1-v2.xlsx')

# %% [markdown]
# ## Basic metadata clean up and data subsetting

# %%
meta_df = df.parse('Supplementary File 1a', header=1)
print(meta_df.shape)
meta_df.head()
# Out:
# (42, 11)
#    Sample Nitrogen source  dilution rate (/h)  \
# 0       1             NH4                0.05
# 1       2             NH4                0.05
# 2       3             NH4                0.05
# 3       4             NH4                0.10
# 4       5             NH4                0.10
#
#    glucose.H2O concentration (g/L)  nitrogen source concentration (g/L)  \
# 0                              7.5                                  0.5
# 1                              7.5                                  0.5
# 2                              7.5                                  0.5
# 3                              7.5                                  5.0
# 4                              7.5                                  5.0
#
#   limiting nutrient  C/N ratio experiment subset  total RNA content (g/gDW)  \
# 0                 N         30                GR                   0.021734
# 1                 N         30                GR                   0.024941
# 2                 N         30                GR                   0.025831
# 3                 C          3                NM                   0.053444
# 4                 C          3                NM                   0.050594
#
#    total protein content (g/gDW) extra notes
# 0                       0.272515         NaN
# 1                       0.250820         NaN
# 2                       0.261097         NaN
# 3                       0.359674         NaN
# 4                       0.377943         NaN

# %% [markdown]
# ## And the same for the expression data

# %%
exp_df = df.parse('Supplementary File 1b', header=1, index_col=1)
print(exp_df.shape)
exp_df.head()
# Out:
# (3127, 94)
#       Accession  protein length        prot.1       prot.2       prot.3  \
# Gene
# SAL1     D6W196             494      4.840234     4.240349     4.525756
# CET1     O13297             549    157.097283   156.674508   169.097093
# FOB1     O13329             566      1.534616     1.245270     1.309993
# RPS9A    O13516             197  11824.166906  9997.847519  9111.935208
# COQ4     O13525             335     86.217705    83.954237     0.000000
#
#              prot.4        prot.5        prot.6       prot.7       prot.8  \
# Gene
# SAL1       8.088604      7.265800      7.831575     4.735927     4.787078
# CET1     198.678218    219.735915    186.590269   117.466448   136.670311
# FOB1       1.551638      1.723677      1.545066     0.766840     1.199747
# RPS9A  15070.518625  14398.262706  16898.705557  8990.481368  9073.912674
# COQ4      80.682606     88.779863     79.627994    79.297220    70.707023
#
#        ...    RNA.41    RNA.42  GR.cluster  NM.cluster  GR.Pearson.r  \
# Gene   ...
# SAL1   ...  0.079206  0.096258           3           1      0.895107
# CET1   ...  0.098678  0.115185           3           1      0.890444
# FOB1   ...  0.069630  0.092075           1           1      0.850031
# RPS9A  ...  0.389067  0.616458           1           1      0.952229
# COQ4   ...  0.206854  0.186202           2           1     -0.025761
#
#        NM.Pearson.r  all.Pearson.r  GR.Spearman.rho  NM.Spearman.rho  \
# Gene
# SAL1       0.105455       0.275134         0.923633        -0.064103
# CET1       0.089570       0.351427         0.828689        -0.037241
# FOB1      -0.224327       0.636860         0.874097        -0.161783
# RPS9A      0.265340       0.822659         0.931889         0.036630
# COQ4      -0.362301      -0.261312         0.105811        -0.331294
#
#        all.Spearman.rho
# Gene
# SAL1           0.273317
# CET1           0.252897
# FOB1           0.343165
# RPS9A          0.434892
# COQ4          -0.295012
#
# [5 rows x 94 columns]

# %% [markdown]
# **Select the columns of interest, normalize so that values are ~molecules per million, and then log-scale**
#
# The only tricky thing here is dealing with zero-values (these only exist in the protein dataset). I thought of a number of solutions, ideally we'd drop them but for a lot of things this becomes a huge pain. Instead, we can just set all 0 values to the smallest observed value anywhere in the dataset and poking around this didn't seem to effect things very much.

# %%
million=1e6

# %%
if data_to_analyze == 'PROTEIN':
    exp_df = exp_df[['{}.{}'.format('prot', i) for i in meta_df['Sample']]]
elif data_to_analyze == 'RNA':
    exp_df = exp_df[['{}.{}'.format('RNA', i) for i in meta_df['Sample']]]

#####
#####Dealing with zero values here, if necessary
current_minimum = exp_df.min().min()
print('Smallest initial value found:', current_minimum)
if current_minimum == 0.:
    print('Making minor adjustments to minimum values to play nice with zeros')
    nonzero_minimum = exp_df[exp_df>0.].min().min()
    exp_df.replace(0., nonzero_minimum, inplace=True)
    print('New minimum value is {}'.format(nonzero_minimum))
else:
    print('No replacement of / dealing with zeros necessary')
print(exp_df.shape)
#####
#####

exp_df.columns = [i for i in meta_df['Sample']]
assert list(meta_df['Sample']) == list(exp_df.columns)
for i in exp_df.columns:
    summy = exp_df[i].sum() ###Get the sum
    exp_df[i] = np.log((exp_df[i]/summy)*million)
    
print(exp_df.shape)
exp_df.head()
# Out:
# Smallest initial value found: 0.0218306749020062
# No replacement of / dealing with zeros necessary
# (3127, 42)
# (3127, 42)
#              1         2         3         4         5         6         7   \
# Gene
# SAL1   4.349298  4.191546  4.316052  4.327372  4.352053  4.378664  4.455308
# CET1   4.640779  4.569720  4.728969  4.698252  4.650936  4.679610  4.695134
# FOB1   4.363864  3.947304  4.500199  4.444517  4.515536  4.433379  4.553852
# RPS9A  6.158881  4.932626  6.152624  6.315496  6.359453  6.314710  6.330474
# COQ4   5.249352  5.917725  5.368879  5.371489  5.269084  5.379912  5.161043
#
#              8         9         10  ...        33        34        35  \
# Gene                                 ...
# SAL1   4.462122  4.452153  4.526110  ...  4.539132  4.563151  4.421305
# CET1   4.798951  4.716328  4.878287  ...  4.512932  4.656884  4.607761
# FOB1   4.505473  4.503823  4.600904  ...  4.176448  4.491079  4.480637
# RPS9A  6.346715  6.410981  6.524541  ...  5.907484  6.157396  6.208520
# COQ4   5.217271  5.223601  5.100415  ...  5.246257  5.189591  5.123624
#
#              36        37        38        39        40        41        42
# Gene
# SAL1   4.564405  4.522836  4.487363  4.482492  4.430928  4.423909  4.500233
# CET1   4.640888  4.629864  4.650512  4.713339  4.694143  4.643723  4.679741
# FOB1   4.344189  4.582468  4.566441  4.497277  4.547323  4.295063  4.455809
# RPS9A  6.142914  6.444128  6.384742  6.300777  6.459150  6.015614  6.357195
# COQ4   5.159536  5.043952  5.076833  5.235309  5.079357  5.383874  5.160038
#
# [5 rows x 42 columns]

# %%
###(slowly/inefficiently) checking for exact duplicate columns
for i, col1 in enumerate(exp_df.columns):
    for col2 in exp_df.columns[i+1:]:
        assert list(exp_df[col1])!= list(exp_df[col2])

# %% [markdown]
# # Averaging between replicates to clean up the data

# %% [markdown]
# ## First getting gene expression averages between replicates and creating a new `dataframe`

# %%
replicate_groups = {}
for sample in meta_df.index:
    ###Make unique identifiers for the samples
    tempy = '{}_{}_{}_{}'.format(*meta_df.loc[sample][['Nitrogen source',\
                                                     'dilution rate (/h)',\
                                                     'glucose.H2O concentration (g/L)',\
                                                     'nitrogen source concentration (g/L)']])
    try:
        replicate_groups[tempy].append(meta_df.loc[sample]['Sample'])
    except KeyError:
        replicate_groups[tempy] = [meta_df.loc[sample]['Sample']]

for key, val in replicate_groups.items():
    print(key, val)
# Out:
# NH4_0.05_7.5_0.5 [1, 2, 3]
# NH4_0.1_7.5_5.0 [4, 5, 6]
# NH4_0.1_7.5_0.5 [7, 8, 9]
# NH4_0.13_7.5_0.5 [10, 11, 12]
# NH4_0.18_7.5_0.5 [13, 14, 15]
# NH4_0.3_7.5_0.5 [16, 17, 18]
# NH4_0.35_7.5_0.5 [19, 20, 21]
# Gln_0.1_7.5_5.53 [22, 23, 24]
# Gln_0.1_1.21_5.53 [25, 26, 27]
# Gln_0.1_6.87_0.55 [28, 29, 30]
# Phe_0.1_7.5_12.35 [31, 32, 33]
# Phe_0.1_7.5_1.24 [34, 35, 36]
# Ile_0.1_7.5_9.81 [37, 38, 39]
# Ile_0.1_7.5_0.98 [40, 41, 42]

# %%
new_exp_df = pd.DataFrame()

for key, val in replicate_groups.items():
    new_exp_df[key] = exp_df[list(val)].mean(axis=1)
print(new_exp_df.shape)
new_exp_df.head()
# Out:
# (3127, 14)
#        NH4_0.05_7.5_0.5  NH4_0.1_7.5_5.0  NH4_0.1_7.5_0.5  NH4_0.13_7.5_0.5  \
# Gene
# SAL1           4.285632         4.352696         4.456528          4.466201
# CET1           4.646489         4.676266         4.736804          4.784382
# FOB1           4.270456         4.464477         4.521049          4.572348
# RPS9A          5.748044         6.329886         6.362723          6.489063
# COQ4           5.511985         5.340162         5.200638          5.078538
#
#        NH4_0.18_7.5_0.5  NH4_0.3_7.5_0.5  NH4_0.35_7.5_0.5  Gln_0.1_7.5_5.53  \
# Gene
# SAL1           4.592553         4.463528          4.475834          4.396805
# CET1           4.744341         4.588284          4.513276          4.709473
# FOB1           4.665816         4.655762          4.685354          4.444711
# RPS9A          6.568587         6.656791          6.679452          6.331893
# COQ4           4.928899         4.556884          4.476369          5.344354
#
#        Gln_0.1_1.21_5.53  Gln_0.1_6.87_0.55  Phe_0.1_7.5_12.35  \
# Gene
# SAL1            4.285736           4.484215           4.521392
# CET1            4.594653           4.678713           4.538710
# FOB1            4.263557           4.402818           4.300268
# RPS9A           6.048702           6.223237           6.130356
# COQ4            5.359399           5.181852           5.242588
#
#        Phe_0.1_7.5_1.24  Ile_0.1_7.5_9.81  Ile_0.1_7.5_0.98
# Gene
# SAL1           4.516287          4.497564          4.451690
# CET1           4.635178          4.664572          4.672536
# FOB1           4.438635          4.548728          4.432732
# RPS9A          6.169610          6.376549          6.277320
# COQ4           5.157584          5.118698          5.207757

# %% [markdown]
# ## Average the growth rates across these replicates in the metadata as well

# %%
for key, vals in replicate_groups.items():
    for numeric_id in vals:
        temp_df = meta_df[meta_df['Sample']==numeric_id]
        assert temp_df.shape[0]==1
        meta_df.at[temp_df.index[0], 'Simple_sample_id'] = key
print(meta_df.shape)
meta_df.head()
# Out:
# (42, 12)
#    Sample Nitrogen source  dilution rate (/h)  \
# 0       1             NH4                0.05
# 1       2             NH4                0.05
# 2       3             NH4                0.05
# 3       4             NH4                0.10
# 4       5             NH4                0.10
#
#    glucose.H2O concentration (g/L)  nitrogen source concentration (g/L)  \
# 0                              7.5                                  0.5
# 1                              7.5                                  0.5
# 2                              7.5                                  0.5
# 3                              7.5                                  5.0
# 4                              7.5                                  5.0
#
#   limiting nutrient  C/N ratio experiment subset  total RNA content (g/gDW)  \
# 0                 N         30                GR                   0.021734
# 1                 N         30                GR                   0.024941
# 2                 N         30                GR                   0.025831
# 3                 C          3                NM                   0.053444
# 4                 C          3                NM                   0.050594
#
#    total protein content (g/gDW) extra notes  Simple_sample_id
# 0                       0.272515         NaN  NH4_0.05_7.5_0.5
# 1                       0.250820         NaN  NH4_0.05_7.5_0.5
# 2                       0.261097         NaN  NH4_0.05_7.5_0.5
# 3                       0.359674         NaN   NH4_0.1_7.5_5.0
# 4                       0.377943         NaN   NH4_0.1_7.5_5.0

# %%
print(meta_df.shape)
group_cols = ['Simple_sample_id']
metric_cols_a = ['total RNA content (g/gDW)', 'total protein content (g/gDW)']
aggs_a = meta_df.groupby(group_cols)[metric_cols_a].mean()

meta_df.drop(metric_cols_a, axis=1, inplace=True)
meta_df.drop_duplicates(subset=group_cols, keep='first', inplace=True)
meta_df = meta_df.merge(right=aggs_a, right_index=True, left_on=group_cols, how='right')
print(meta_df.shape)
meta_df.head()
# Out:
# (42, 12)
# (14, 12)
#     Sample Nitrogen source  dilution rate (/h)  \
# 0        1             NH4                0.05
# 3        4             NH4                0.10
# 6        7             NH4                0.10
# 9       10             NH4                0.13
# 12      13             NH4                0.18
#
#     glucose.H2O concentration (g/L)  nitrogen source concentration (g/L)  \
# 0                               7.5                                  0.5
# 3                               7.5                                  5.0
# 6                               7.5                                  0.5
# 9                               7.5                                  0.5
# 12                              7.5                                  0.5
#
#    limiting nutrient  C/N ratio experiment subset extra notes  \
# 0                  N         30                GR         NaN
# 3                  C          3                NM         NaN
# 6                  N         30            GR, NM         NaN
# 9                  N         30                GR         NaN
# 12                 N         30                GR         NaN
#
#     Simple_sample_id  total RNA content (g/gDW)  total protein content (g/gDW)
# 0   NH4_0.05_7.5_0.5                   0.024169                       0.261477
# 3    NH4_0.1_7.5_5.0                   0.050000                       0.358024
# 6    NH4_0.1_7.5_0.5                   0.025297                       0.225573
# 9   NH4_0.13_7.5_0.5                   0.025831                       0.275686
# 12  NH4_0.18_7.5_0.5                   0.038539                       0.286470

# %%
meta_df['Doubling_time'] = np.log(2)/meta_df['dilution rate (/h)']
meta_df['Growth Rate (1/hr)'] = meta_df['dilution rate (/h)']
assert list(meta_df['Simple_sample_id']) == list(new_exp_df.columns)

# %% [markdown]
# # Construct a third `dataframe` containing expression data summary stats

# %%
exp_summary_df = new_exp_df.apply(pd.DataFrame.describe, axis=1)

# %%
col_listy = []
for col in exp_summary_df.columns:
    if '%' not in col:
        col_listy.append(col)
    else:
        col_listy.append(col.replace('%', '_percentile'))
print(col_listy)
exp_summary_df.columns = col_listy
# Out:
# ['count', 'mean', 'std', 'min', '25_percentile', '50_percentile', '75_percentile', 'max']

# %%
exp_summary_df['cv'] = exp_summary_df['std']/exp_summary_df['mean']
exp_summary_df['noise'] = exp_summary_df['std'].pow(2)/exp_summary_df['mean'].pow(2)

# %%
slopes = []
pearsons = []
spearmans = []
for gene in exp_summary_df.index:
    a, b, c, d, e = stats.linregress(new_exp_df.loc[gene], meta_df['dilution rate (/h)']) 
    slopes.append(a)
    pearsons.append(c)
    rho, p = stats.spearmanr(new_exp_df.loc[gene], meta_df['dilution rate (/h)'], nan_policy='omit')
    spearmans.append(rho)
    
exp_summary_df['lin_slope'] = slopes
exp_summary_df['lin_r'] = pearsons
exp_summary_df['spearmans_rho'] = spearmans

# %% [markdown]
# # Save some files

# %%
print(new_exp_df.shape)
print(meta_df.shape)
print(exp_summary_df.shape)
new_exp_df.to_csv('../Data/processed_data/processed_expression_scer_{}.tsv'.format(data_to_analyze), sep='\t')
meta_df.to_csv('../Data/processed_data/processed_metadata_scer_{}.tsv'.format(data_to_analyze), sep='\t')
exp_summary_df.to_csv('../Data/processed_data/processed_expression_summary_scer_{}.tsv'.format(data_to_analyze), sep='\t')
# Out:
# (3127, 14)
# (14, 14)
# (3127, 13)

# %% [markdown]
# # Get a thinned down set as a robustness check?
#
# Too few samples to do this step here.
